# %% [markdown]
# <a href="https://colab.research.google.com/github/sameermdanwer/python-assignment-/blob/main/Statistics_Advance_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.
#
# The t-test and z-test are both statistical tests used to determine if there is a significant difference between the means of two groups. However, they differ in their application and underlying assumptions. Here’s a breakdown of their differences and examples of when to use each.
#
# # Key Differences
# 1. Sample Size:
#
# * Z-test: Used when the sample size is large (typically
# 𝑛
# >
# 30
# n>30). It can also be used for smaller samples if the population standard deviation is known.
# * T-test: Used when the sample size is small (
# 𝑛
# ≤
# 30
# n≤30) and the population standard deviation is unknown.
# 2. Population Standard Deviation:
#
# * Z-test: Requires knowledge of the population standard deviation (
# 𝜎
# σ).
# * T-test: Uses the sample standard deviation (
# 𝑠
# s) as an estimate of the population standard deviation.
# 3. Distribution:
#
# * Z-test: Assumes that the sampling distribution of the mean is normal, which is often valid due to the Central Limit Theorem for larger samples.
# * T-test: Assumes that the data is approximately normally distributed, especially important for smaller sample sizes.
# 4. Test Statistic:
#
# * Z-test: Uses the z-statistic calculated as:
# 𝑧
# =
# 𝑥
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# z=
# σ/
# n
# ​
#
# x
# ˉ
#  −μ
# ​
#
# * T-test: Uses the t-statistic calculated as:
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# t=
# s/
# n
# ​
#
# x
# ˉ
#  −μ
# ​
#
# # Example Scenarios
# #  Z-test Example:
# * Scenario: A quality control manager at a factory wants to determine if the average weight of a product is equal to the specification of 500 grams. They take a random sample of 100 products, and the population standard deviation is known to be 15 grams.
#
# * Appropriate Test: Z-test
# * Reason: The sample size is large (
# 𝑛
# =
# 100
# n=100), and the population standard deviation is known.
# # T-test Example:
# Scenario: A researcher wants to assess whether a new teaching method is more effective than the traditional method. They conduct an experiment with a random sample of 25 students using the new method and find that their average test score is 82 with a standard deviation of 5. The researcher does not know the population standard deviation.

# %% [markdown]
# # Q2: Differentiate between one-tailed and two-tailed tests.
#
# One-tailed and two-tailed tests are both types of hypothesis tests used to determine if there is a significant effect or difference in statistical analysis. The main difference between them lies in how they assess the direction of the effect. Here’s a breakdown of the key differences:
#
# # One-Tailed Test
# 1. Definition: A one-tailed test evaluates the direction of the relationship or effect. It tests for the possibility of the relationship in one direction only.
#
# 2. Hypotheses:
#
# * Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): Typically states that there is no effect or no difference.
# * Alternative Hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  : States that there is an effect or difference in a specific direction.
# * Example:
# 𝐻
# 0
# :
# 𝜇
# =
# 𝜇
# 0
# H
# 0
# ​
#  :μ=μ
# 0
# ​
#
# 𝐻
# 1
# :
# 𝜇
# >
# 𝜇
# 0
# H
# 1
# ​
#  :μ>μ
# 0
# ​
#   (Right-tailed)
# or
# 𝐻
# 1
# :
# 𝜇
# <
# 𝜇
# 0
# H
# 1
# ​
#  :μ<μ
# 0
# ​
#   (Left-tailed)
# 3. Critical Region: The critical region for rejection of the null hypothesis is located entirely in one tail of the distribution (either the left or the right).
#
# 4. Usage Example:
#
# A company claims that its new product lasts longer than the previous model. A one-tailed test would be appropriate if the research hypothesis is that the new model has a longer average lifespan.
# # Two-Tailed Test
# 1. Definition: A two-tailed test evaluates the possibility of the relationship or effect in both directions. It tests for the possibility of the relationship being either greater than or less than the null hypothesis.
#
# 2. Hypotheses:
#
# * Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): States that there is no effect or no difference.
# * Alternative Hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  ): States that there is an effect or difference in either direction.
# * Example:
# 𝐻
# 0
# :
# 𝜇
# =
# 𝜇
# 0
# H
# 0
# ​
#  :μ=μ
# 0
# ​
#
# 𝐻
# 1
# :
# 𝜇
# ≠
# 𝜇
# 0
# H
# 1
# ​
#  :μ
# 
# =μ
# 0
# ​
#
# 3. Critical Region: The critical region for rejection of the null hypothesis is split between both tails of the distribution.
#
# 4. Usage Example:
#
# A researcher wants to test whether a new drug affects blood pressure differently than a placebo. A two-tailed test is appropriate if they are interested in detecting both increases and decreases in blood pressure.

# %% [markdown]
# # Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.
#
# In hypothesis testing, Type I and Type II errors are two potential mistakes that can occur when making decisions based on statistical tests. Understanding these errors is crucial for interpreting the results of hypothesis tests and for making informed decisions in research and practical applications.
#
# # Type I Error (False Positive)
# * Definition: A Type I error occurs when the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is rejected when it is actually true. In simpler terms, it is the incorrect conclusion that there is an effect or a difference when, in fact, none exists.
#
# Significance Level (
# 𝛼
# α): The probability of making a Type I error is denoted by
# 𝛼
# α, which is the significance level set for the hypothesis test (e.g.,
# 𝛼
# =
# 0.05
# α=0.05 means there is a 5% risk of committing a Type I error).
#
# * Example Scenario:
#
# * Medical Testing: Suppose a new test for a disease is developed, and the null hypothesis states that a patient does not have the disease. If the test indicates that the patient has the disease (rejecting
# 𝐻
# 0
# H
# 0
# ​
#  ) when they actually do not (the null hypothesis is true), this is a Type I error. This could lead to unnecessary treatments and anxiety for the patient.
# # Type II Error (False Negative)
# * Definition: A Type II error occurs when the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is not rejected when it is actually false. In other words, it is the failure to detect an effect or a difference that actually exists.
#
# * Beta Level (
# 𝛽
# β): The probability of making a Type II error is denoted by
# 𝛽
# β. The power of the test, which is the probability of correctly rejecting the null hypothesis when it is false, is calculated as
# 1
# −
# 𝛽
# 1−β.
#
# * Example Scenario:
#
# Quality Control: In a manufacturing process, a company tests a batch of products to determine whether the production meets quality standards (the null hypothesis is that the batch is acceptable). If the test fails to reject the null hypothesis (concluding that the batch is acceptable) when it actually contains defective products (the null hypothesis is false), this is a Type II error. This could result in defective products reaching customers, leading to dissatisfaction and potential harm.

# %% [markdown]
# # Q4: Explain Bayes's theorem with an example.
#
# Bayes's theorem is a fundamental concept in probability theory and statistics that describes how to update the probability of a hypothesis based on new evidence. It provides a mathematical framework for revising beliefs in light of new data and is widely used in various fields, including statistics, finance, and machine learning.
#
# # Bayes's Theorem
# The theorem is formally expressed as follows:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# * P(A∣B) is the posterior probability: the probability of event
# 𝐴
# A occurring given that
# 𝐵
# B is true.
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# * P(B∣A) is the likelihood: the probability of event
# 𝐵
# B occurring given that
# 𝐴
# A is true.
# 𝑃
# (
# 𝐴
# )
# * P(A) is the prior probability: the initial probability of event
# 𝐴
# A occurring before observing evidence
# 𝐵
# B.
# 𝑃
# (
# 𝐵
# )
# * P(B) is the marginal probability: the total probability of event
# 𝐵
# B occurring, which can be calculated as:
# 𝑃
# (
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# +
# 𝑃
# (
# 𝐵
# ∣
# ¬
# 𝐴
# )
# ⋅
# 𝑃
# (
# ¬
# 𝐴
# )
# P(B)=P(B∣A)⋅P(A)+P(B∣¬A)⋅P(¬A)
# Where
# ¬
# 𝐴
# ¬A represents the complement of event
# 𝐴
# A.
#
# # Example Scenario: Medical Testing
# Let's illustrate Bayes's theorem with an example involving a medical test for a disease.
#
# * Problem Statement
# Suppose a certain disease affects 1% of a population (
# 𝑃
# (
# 𝐷
# )
# =
# 0.01
# P(D)=0.01), and there is a test for this disease. The test has the following characteristics:
#
# * If a person has the disease, the probability of testing positive is 90% (
# 𝑃
# (
# 𝑇
# +
# ∣
# 𝐷
# )
# =
# 0.9
# P(T
# +
#  ∣D)=0.9).
# * If a person does not have the disease, the probability of testing positive (false positive) is 5% (
# 𝑃
# (
# 𝑇
# +
# ∣
# ¬
# 𝐷
# )
# =
# 0.05
# P(T
# +
#  ∣¬D)=0.05).
# We want to find the probability that a person actually has the disease given that they tested positive (
# 𝑃
# (
# 𝐷
# ∣
# 𝑇
# +
# )
# P(D∣T
# +
#  )).

# %% [markdown]
# # Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.
#
# A confidence interval is a range of values that is used to estimate the true value of a population parameter (such as a population mean or proportion) with a specified level of confidence. It provides an estimate of the uncertainty associated with a sample statistic, reflecting the variability inherent in sampling.
#
# # Key Components of a Confidence Interval
# 1. Point Estimate: This is the sample statistic (like the sample mean) that serves as the best estimate of the population parameter.
#
# 2. Margin of Error: This indicates how much the point estimate might vary from the true population parameter. It is calculated based on the variability of the sample and the desired confidence level.
#
# 3. Confidence Level: This indicates the degree of certainty that the interval contains the population parameter. Common confidence levels are 90%, 95%, and 99%.
#
# # Formula for Confidence Interval
# For a population mean, the confidence interval can be calculated using the following formula:
#
# Confidence Interval
# =
# 𝑥
# ˉ
# ±
# 𝑧
# (
# 𝑠
# 𝑛
# )
# Confidence Interval=
# x
# ˉ
#  ±z(
# n
# ​
#
# s
# ​
#  )
# Where:
#
# 𝑥
# ˉ
# * x
# ˉ
#   = sample mean
# 𝑧
# * z = z-score corresponding to the desired confidence level (from the standard normal distribution)
# 𝑠
# * s = sample standard deviation
# 𝑛
# * n = sample size
# # Example: Calculating a Confidence Interval
# Scenario
# Suppose a researcher wants to estimate the average height of adult males in a city. They take a random sample of 50 adult males and find the following:
#
# * Sample mean height (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 175 cm
# * Sample standard deviation (
# 𝑠
# s) = 10 cm
# * Desired confidence level = 95%
# # Step 1: Find the Z-Score
# For a 95% confidence level, the critical z-value (z-score) can be found using a z-table. For a two-tailed test at 95%, the z-score is approximately:
#
# 𝑧
# ≈
# 1.96
# z≈1.96
# # Step 2: Calculate the Standard Error (SE)
# The standard error of the sample mean is calculated as follows:
#
# SE
# =
# 𝑠
# 𝑛
# =
# 10
# 50
# ≈
# 10
# 7.071
# ≈
# 1.4142
# SE=
# n
# ​
#
# s
# ​
#  =
# 50
# ​
#
# 10
# ​
#  ≈
# 7.071
# 10
# ​
#  ≈1.4142
# # Step 3: Calculate the Margin of Error (ME)
# The margin of error can now be calculated:
#
# Margin of Error
# =
# 𝑧
# ×
# SE
# =
# 1.96
# ×
# 1.4142
# ≈
# 2.774
# Margin of Error=z×SE=1.96×1.4142≈2.774
# # Step 4: Calculate the Confidence Interval
# Finally, we can calculate the confidence interval:
#
# \text{Confidence Interval} = \bar{x} \pm \text{Margin of Error
# Confidence Interval
# =
# 175
# ±
# 2.774
# Confidence Interval=175±2.774
# This results in:
#
# Lower limit
# =
# 175
# −
# 2.774
# ≈
# 172.226
# Lower limit=175−2.774≈172.226
# Upper limit
# =
# 175
# +
# 2.774
# ≈
# 177.774
# Upper limit=175+2.774≈177.774

# %% [markdown]
# # Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.
#
# Let’s illustrate how to use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence with a sample problem.
#
# Sample Problem: Email Spam Filter
# Scenario: A company has developed an email spam filter and wants to calculate the probability that an email is actually spam given that it has been marked as spam by the filter.
#
# Given Data:
# 1. Prior Probability of Spam: The probability that any given email is spam,
# 𝑃
# (
# 𝑆
# )
# =
# 0.2
# P(S)=0.2 (20% of all emails are spam).
# 2. Prior Probability of Not Spam: The probability that an email is not spam,
# 𝑃
# (
# 𝑁
# )
# =
# 1
# −
# 𝑃
# (
# 𝑆
# )
# =
# 0.8
# P(N)=1−P(S)=0.8.
# 3. Likelihood of Spam Email Being Marked as Spam: The probability that an email is marked as spam given that it is actually spam,
# 𝑃
# (
# 𝑀
# ∣
# 𝑆
# )
# =
# 0.9
# P(M∣S)=0.9 (90% of spam emails are correctly identified).
# 4. Likelihood of Not Spam Email Being Marked as Spam: The probability that an email is marked as spam given that it is not spam (false positive),
# 𝑃
# (
# 𝑀
# ∣
# 𝑁
# )
# =
# 0.05
# P(M∣N)=0.05 (5% of non-spam emails are incorrectly marked as spam).
# # Step 1: Calculate
# 𝑃
# (
# 𝑀
# )
# P(M)
# To apply Bayes' Theorem, we first need to calculate the total probability of an email being marked as spam,
# 𝑃
# (
# 𝑀
# )
# P(M):
#
# 𝑃
# (
# 𝑀
# )
# =
# 𝑃
# (
# 𝑀
# ∣
# 𝑆
# )
# ⋅
# 𝑃
# (
# 𝑆
# )
# +
# 𝑃
# (
# 𝑀
# ∣
# 𝑁
# )
# ⋅
# 𝑃
# (
# 𝑁
# )
# P(M)=P(M∣S)⋅P(S)+P(M∣N)⋅P(N)
# Substituting in the values:
#
# 𝑃
# (
# 𝑀
# )
# =
# (
# 0.9
# ⋅
# 0.2
# )
# +
# (
# 0.05
# ⋅
# 0.8
# )
# P(M)=(0.9⋅0.2)+(0.05⋅0.8)
# 𝑃
# (
# 𝑀
# )
# =
# 0.18
# +
# 0.04
# =
# 0.22
# P(M)=0.18+0.04=0.22
# # Step 2: Apply Bayes' Theorem
# Now we can apply Bayes' Theorem to find the probability that an email is actually spam given that it has been marked as spam,
# 𝑃
# (
# 𝑆
# ∣
# 𝑀
# )
# P(S∣M):
#
# 𝑃
# (
# 𝑆
# ∣
# 𝑀
# )
# =
# 𝑃
# (
# 𝑀
# ∣
# 𝑆
# )
# ⋅
# 𝑃
# (
# 𝑆
# )
# 𝑃
# (
# 𝑀
# )
# P(S∣M)=
# P(M)
# P(M∣S)⋅P(S)
# ​
#
# Substituting the known values:
#
# 𝑃
# (
# 𝑆
# ∣
# 𝑀
# )
# =
# (
# 0.9
# ⋅
# 0.2
# )
# 0.22
# P(S∣M)=
# 0.22
# (0.9⋅0.2)
# ​
#
# 𝑃
# (
# 𝑆
# ∣
# 𝑀
# )
# =
# 0.18
# 0.22
# ≈
# 0.8181
# P(S∣M)=
# 0.22
# 0.18
# ​
#  ≈0.8181

# %% [markdown]
# # Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.
#
# To calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5, we can use the following steps:
#
# # Step 1: Gather Information
# * Sample Mean (
# 𝑥
# ˉ
# x
# ˉ
#  ): 50
# * Sample Standard Deviation (
# 𝑠
# s): 5
# * Sample Size (
# 𝑛
# n): Since it isn't provided, we'll assume a sample size of 30, which is a common choice for such calculations.
# # Step 2: Determine the Z-Score
# For a 95% confidence interval, the critical z-value (z-score) can be found using a z-table. For a two-tailed test at 95%, the z-score is approximately:
#
# 𝑧
# ≈
# 1.96
# z≈1.96
# # Step 3: Calculate the Standard Error (SE)
# The standard error of the sample mean is calculated as follows:
#
# SE
# =
# 𝑠
# 𝑛
# =
# 5
# 30
# ≈
# 5
# 5.477
# ≈
# 0.913
# SE=
# n
# ​
#
# s
# ​
#  =
# 30
# ​
#
# 5
# ​
#  ≈
# 5.477
# 5
# ​
#  ≈0.913
# # Step 4: Calculate the Margin of Error (ME)
# The margin of error can now be calculated:
#
# Margin of Error
# =
# 𝑧
# ×
# SE
# =
# 1.96
# ×
# 0.913
# ≈
# 1.79
# Margin of Error=z×SE=1.96×0.913≈1.79
# # Step 5: Calculate the Confidence Interval
# Finally, we can calculate the confidence interval:
#
# Confidence Interval
# =
# 𝑥
# ˉ
# ±
# Margin of Error
# Confidence Interval=
# x
# ˉ
#  ±Margin of Error
# Confidence Interval
# =
# 50
# ±
# 1.79
# Confidence Interval=50±1.79
# This results in:
#
# Lower limit
# =
# 50
# −
# 1.79
# ≈
# 48.21
# Lower limit=50−1.79≈48.21
# Upper limit
# =
# 50
# +
# 1.79
# ≈
# 51.79
# Upper limit=50+1.79≈51.79

# %% [markdown]
# # Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
#
# The margin of error in a confidence interval quantifies the range of uncertainty around a sample estimate (such as a sample mean). It represents how much the sample result may differ from the true population parameter due to sampling variability. The margin of error is crucial in interpreting confidence intervals, as it provides an upper and lower limit around the estimate.
#
# # Formula for Margin of Error
# For a population mean, the margin of error (ME) can be calculated using the following formula:
#
# Margin of Error
# =
# 𝑧
# ×
# SE
# Margin of Error=z×SE
# Where:
#
# 𝑧
# * z = z-score corresponding to the desired confidence level (e.g., 1.96 for a 95% confidence level).
# SE
# * SE = standard error of the sample mean, calculated as:
# SE
# =
# 𝑠
# 𝑛
# SE=
# n
# ​
#
# s
# ​
#
# Where:
#
# 𝑠
# * s = sample standard deviation.
# 𝑛
# * n = sample size.
# # Effect of Sample Size on Margin of Error
# The margin of error is inversely related to the sample size. As the sample size increases, the standard error decreases because the sample mean becomes a more accurate estimate of the population mean. This leads to a smaller margin of error. Conversely, a smaller sample size results in a larger standard error and a larger margin of error.
#
# # Example Scenario
# Scenario: Estimating the average height of students in a university.
#
# 1. Smaller Sample Size: Suppose a researcher takes a sample of 25 students and finds a sample mean height of 170 cm with a standard deviation of 10 cm.
#
# * Calculate the standard error:
#
# SE
# =
# 10
# 25
# =
# 10
# 5
# =
# 2
# SE=
# 25
# ​
#
# 10
# ​
#  =
# 5
# 10
# ​
#  =2
# * For a 95% confidence level, the z-score is approximately 1.96.
#
# * Calculate the margin of error:
#
# Margin of Error
# =
# 1.96
# ×
# 2
# =
# 3.92
# Margin of Error=1.96×2=3.92
# * The confidence interval is:
#
# (
# 170
# −
# 3.92
# ,
# 170
# +
# 3.92
# )
# =
# (
# 166.08
# ,
# 173.92
# )
# (170−3.92,170+3.92)=(166.08,173.92)
# 2. Larger Sample Size: Now, suppose the researcher takes a larger sample of 100 students with the same mean height of 170 cm and standard deviation of 10 cm.
#
# * Calculate the standard error:
#
# SE
# =
# 10
# 100
# =
# 10
# 10
# =
# 1
# SE=
# 100
# ​
#
# 10
# ​
#  =
# 10
# 10
# ​
#  =1
# * Calculate the margin of error:
#
# Margin of Error
# =
# 1.96
# ×
# 1
# =
# 1.96
# Margin of Error=1.96×1=1.96
# * The confidence interval is:
#
# (
# 170
# −
# 1.96
# ,
# 170
# +
# 1.96
# )
# =
# (
# 168.04
# ,
# 171.96
# )
# (170−1.96,170+1.96)=(168.04,171.96)

# %% [markdown]
# # Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.
#
# To calculate the z-score for a given data point, we can use the following formula:
#
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
# z=
# σ
# (X−μ)
# ​
#
# Where:
#
# 𝑋
# * X = value of the data point
# 𝜇
# * μ = population mean
# 𝜎
# * σ = population standard deviation
# # Given Data
# * Data point value (
# 𝑋
# X) = 75
# * Population mean (
# 𝜇
# μ) = 70
# * Population standard deviation (
# 𝜎
# σ) = 5
# # Step 1: Calculate the z-score
# Substituting the values into the formula:
#
# 𝑧
# =
# (
# 75
# −
# 70
# )
# 5
# z=
# 5
# (75−70)
# ​
#
# 𝑧
# =
# 5
# 5
# =
# 1
# z=
# 5
# 5
# ​
#  =1
# # Step 2: Interpret the Result
# The calculated z-score is 1.
#
# Interpretation:
# * A z-score of 1 means that the data point (75) is 1 standard deviation above the mean (70).
# * This indicates that the value of 75 is higher than the average population value, and it gives context to how unusual or typical this data point is within the distribution.
# * In a standard normal distribution, about 68% of the data points fall within 1 standard deviation of the mean (both above and below). Therefore, a z-score of 1 suggests that the data point of 75 is higher than approximately 84% of the data points in a normal distribution (since it includes everything below
# 𝑧
# =
# 1
# z=1).
# This information can be valuable in various contexts, such as identifying outliers, understanding distribution characteristics, or making decisions based on the data's position relative to the mean.

# %% [markdown]
# # Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.
#
# To conduct a hypothesis test to determine if the new weight loss drug is significantly effective at a 95% confidence level using a t-test, we can follow these steps:
#
# # Step 1: Formulate the Hypotheses
# 1. Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): The drug has no effect on weight loss, which means the mean weight loss is equal to zero.
#
# 𝐻
# 0
# :
# 𝜇
# =
# 0
# H
# 0
# ​
#  :μ=0
# 2. Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): The drug has a significant effect on weight loss, which means the mean weight loss is greater than zero.
#
# 𝐻
# 𝑎
# :
# 𝜇
# >
# 0
# H
# a
# ​
#  :μ>0
# # Step 2: Gather Information
# * Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 6 pounds
# * Population mean under the null hypothesis (
# 𝜇
# 0
# μ
# 0
# ​
#  ) = 0 pounds
# * Sample standard deviation (
# 𝑠
# s) = 2.5 pounds
# * Sample size (
# 𝑛
# n) = 50
# # Step 3: Calculate the Test Statistic
# We will use the t-test formula for the one-sample t-test:
#
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# 𝑛
# t=
# n
# ​
#
# s
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Substituting the values:
#
# 1. Calculate the standard error (SE):
# SE
# =
# 𝑠
# 𝑛
# =
# 2.5
# 50
# ≈
# 2.5
# 7.071
# ≈
# 0.3536
# SE=
# n
# ​
#
# s
# ​
#  =
# 50
# ​
#
# 2.5
# ​
#  ≈
# 7.071
# 2.5
# ​
#  ≈0.3536
# 2. Calculate the t-statistic:
# 𝑡
# =
# 6
# −
# 0
# 0.3536
# ≈
# 6
# 0.3536
# ≈
# 16.96
# t=
# 0.3536
# 6−0
# ​
#  ≈
# 0.3536
# 6
# ​
#  ≈16.96
# # Step 4: Determine the Degrees of Freedom
# The degrees of freedom (
# 𝑑
# 𝑓
# df) for a one-sample t-test is calculated as:
#
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# =
# 50
# −
# 1
# =
# 49
# df=n−1=50−1=49
# # Step 5: Find the Critical t-Value
# Using a t-table or calculator, for a one-tailed test at a 95% confidence level with 49 degrees of freedom, the critical t-value is approximately:
#
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# 𝑖
# 𝑐
# 𝑎
# 𝑙
# ≈
# 1.676
# t
# critical
# ​
#  ≈1.676
# # Step 6: Compare the Test Statistic to the Critical Value
# Now we compare our calculated t-statistic with the critical t-value:
#
# Calculated t-statistic: 16.96
# Critical t-value: 1.676
# # Step 7: Conclusion
# Since 16.96 (test statistic) is much greater than 1.676 (critical value), we reject the null hypothesis.

# %% [markdown]
# # Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.
#
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job, we can use the formula for the confidence interval for a proportion:
#
# 𝐶
# 𝐼
# =
# 𝑝
# ^
# ±
# 𝑧
# ⋅
# 𝑝
# ^
# (
# 1
# −
# 𝑝
# ^
# )
# 𝑛
# CI=
# p
# ^
# ​
#  ±z⋅
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# # Given Data
# * Sample size (
# 𝑛
# n) = 500
# * Sample proportion (
# 𝑝
# ^
# p
# ^
# ​
#  ) = 0.65 (65% reported being satisfied)
# # Step 1: Calculate the Standard Error (SE)
# First, we need to calculate the standard error of the proportion:
#
# 𝑆
# 𝐸
# =
# 𝑝
# ^
# (
# 1
# −
# 𝑝
# ^
# )
# 𝑛
# SE=
# n
# p
# ^
# ​
#  (1−
# p
# ^
# ​
#  )
# ​
#
# ​
#
# Substituting the values:
#
# 𝑆
# 𝐸
# =
# 0.65
# (
# 1
# −
# 0.65
# )
# 500
# =
# 0.65
# ×
# 0.35
# 500
# =
# 0.2275
# 500
# =
# 0.000455
# ≈
# 0.0213
# SE=
# 500
# 0.65(1−0.65)
# ​
#
# ​
#  =
# 500
# 0.65×0.35
# ​
#
# ​
#  =
# 500
# 0.2275
# ​
#
# ​
#  =
# 0.000455
# ​
#  ≈0.0213
# # Step 2: Find the z-Score
# For a 95% confidence level, the critical z-value is approximately:
#
# 𝑧
# ≈
# 1.96
# z≈1.96
# # Step 3: Calculate the Margin of Error (ME)
# Now we can calculate the margin of error:
#
# 𝑀
# 𝐸
# =
# 𝑧
# ⋅
# 𝑆
# 𝐸
# =
# 1.96
# ⋅
# 0.0213
# ≈
# 0.0417
# ME=z⋅SE=1.96⋅0.0213≈0.0417
# # Step 4: Calculate the Confidence Interval
# Finally, we calculate the confidence interval:
#
# 𝐶
# 𝐼
# =
# 𝑝
# ^
# ±
# 𝑀
# 𝐸
# CI=
# p
# ^
# ​
#  ±ME
#  * Calculating the lower and upper limits:
#
# 1. Lower limit:
# 𝑝
# ^
# −
# 𝑀
# 𝐸
# =
# 0.65
# −
# 0.0417
# ≈
# 0.6083
# p
# ^
# ​
#  −ME=0.65−0.0417≈0.6083
# 2. Upper limit:
# 𝑝
# ^
# +
# 𝑀
# 𝐸
# =
# 0.65
# +
# 0.0417
# ≈
# 0.6917
# p
# ^
# ​
#  +ME=0.65+0.0417≈0.6917

# %% [markdown]
# # Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.
#
# To conduct a hypothesis test to determine if there is a significant difference in student performance between two teaching methods using a t-test, we can follow these steps:
#
# # Step 1: Formulate the Hypotheses
# 1. Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): There is no significant difference in student performance between the two teaching methods.
#
# 𝐻
# 0
# :
# 𝜇
# 𝐴
# =
# 𝜇
# 𝐵
# H
# 0
# ​
#  :μ
# A
# ​
#  =μ
# B
# ​
#
# 2. Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): There is a significant difference in student performance between the two teaching methods.
#
# 𝐻
# 𝑎
# :
# 𝜇
# 𝐴
# ≠
# 𝜇
# 𝐵
# H
# a
# ​
#  :μ
# A
# ​
#
# 
# =μ
# B
# ​
#
# # Step 2: Gather Information
# * Sample A:
#
# * Mean (
# 𝑥
# ˉ
# 𝐴
# x
# ˉ
#
# A
# ​
#  ) = 85
# * Standard deviation (
# 𝑠
# 𝐴
# s
# A
# ​
#  ) = 6
# * Sample size (
# 𝑛
# 𝐴
# n
# A
# ​
#  ) = Not given, let's assume
# 𝑛
# 𝐴
# =
# 30
# n
# A
# ​
#  =30
# * Sample B:
#
# * Mean (
# 𝑥
# ˉ
# 𝐵
# x
# ˉ
#
# B
# ​
#  ) = 82
# * Standard deviation (
# 𝑠
# 𝐵
# s
# B
# ​
#  ) = 5
# * Sample size (
# 𝑛
# 𝐵
# n
# B
# ​
#  ) = Not given, let's assume
# 𝑛
# 𝐵
# =
# 30
# n
# B
# ​
#  =30
# # Step 3: Calculate the Test Statistic
# We will use the formula for the t-test for independent samples:
#
# 𝑡
# =
# 𝑥
# ˉ
# 𝐴
# −
# 𝑥
# ˉ
# 𝐵
# 𝑠
# 𝐴
# 2
# 𝑛
# 𝐴
# +
# 𝑠
# 𝐵
# 2
# 𝑛
# 𝐵
# t=
# n
# A
# ​
#
# s
# A
# 2
# ​
#
# ​
#  +
# n
# B
# ​
#
# s
# B
# 2
# ​
#
# ​
#
# ​
#
# x
# ˉ
#
# A
# ​
#  −
# x
# ˉ
#
# B
# ​
#
# ​
#
# Substituting the values:
#
# 1. Calculate the standard error (SE):
# 𝑆
# 𝐸
# =
# 𝑠
# 𝐴
# 2
# 𝑛
# 𝐴
# +
# 𝑠
# 𝐵
# 2
# 𝑛
# 𝐵
# =
# 6
# 2
# 30
# +
# 5
# 2
# 30
# =
# 36
# 30
# +
# 25
# 30
# =
# 61
# 30
# ≈
# 2.0333
# ≈
# 1.426
# SE=
# n
# A
# ​
#
# s
# A
# 2
# ​
#
# ​
#  +
# n
# B
# ​
#
# s
# B
# 2
# ​
#
# ​
#
# ​
#  =
# 30
# 6
# 2
#
# ​
#  +
# 30
# 5
# 2
#
# ​
#
# ​
#  =
# 30
# 36
# ​
#  +
# 30
# 25
# ​
#
# ​
#  =
# 30
# 61
# ​
#
# ​
#  ≈
# 2.0333
# ​
#  ≈1.426
# 2. Calculate the t-statistic:
# 𝑡
# =
# 85
# −
# 82
# 1.426
# =
# 3
# 1.426
# ≈
# 2.1
# t=
# 1.426
# 85−82
# ​
#  =
# 1.426
# 3
# ​
#  ≈2.1
# # Step 4: Determine the Degrees of Freedom
# The degrees of freedom (
# 𝑑
# 𝑓
# df) for independent samples can be calculated using the following formula:
#
# 𝑑
# 𝑓
# =
# 𝑛
# 𝐴
# +
# 𝑛
# 𝐵
# −
# 2
# =
# 30
# +
# 30
# −
# 2
# =
# 58
# df=n
# A
# ​
#  +n
# B
# ​
#  −2=30+30−2=58
# # Step 5: Find the Critical t-Value
# Using a t-table, for a two-tailed test at a significance level of
# 0.01
# 0.01 with
# 58
# 58 degrees of freedom, the critical t-value is approximately:
#
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# 𝑖
# 𝑐
# 𝑎
# 𝑙
# ≈
# ±
# 2.660
# t
# critical
# ​
#  ≈±2.660
# # Step 6: Compare the Test Statistic to the Critical Value
# Now we compare our calculated t-statistic with the critical t-value:
#
# * Calculated t-statistic: 2.1
# * Critical t-value: ±2.660
# # Step 7: Conclusion
# Since 2.1 (test statistic) is less than 2.660 (critical value), we fail to reject the null hypothesis.
#
# # Final Conclusion
# There is not enough evidence at the
# 0.01
# 0.01 significance level to conclude that there is a significant difference in student performance between the two teaching methods. The test suggests that the performance scores of the two methods are statistically similar based on the samples tested.

# %% [markdown]
# # Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.
#
# To calculate the 90% confidence interval for the true population mean based on the sample mean, we can use the formula for the confidence interval for a population mean when the population standard deviation is known:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑧
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±z⋅
# n
# ​
#
# σ
# ​
#
# # Given Data
# * Population mean (
# 𝜇
# μ) = 60 (not needed for the calculation, but provided)
# * Population standard deviation (
# 𝜎
# σ) = 8
# * Sample size (
# 𝑛
# n) = 50
# * Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 65
# # Step 1: Find the z-Score
# For a 90% confidence level, the critical z-value can be found using a z-table. The critical z-value for a 90% confidence level (which leaves 5% in each tail) is approximately:
#
# 𝑧
# ≈
# 1.645
# z≈1.645
# # Step 2: Calculate the Standard Error (SE)
# The standard error (SE) is calculated as follows:
#
# 𝑆
# 𝐸
# =
# 𝜎
# 𝑛
# =
# 8
# 50
# ≈
# 8
# 7.071
# ≈
# 1.414
# SE=
# n
# ​
#
# σ
# ​
#  =
# 50
# ​
#
# 8
# ​
#  ≈
# 7.071
# 8
# ​
#  ≈1.414
# # Step 3: Calculate the Margin of Error (ME)
# Now we can calculate the margin of error:
#
# 𝑀
# 𝐸
# =
# 𝑧
# ⋅
# 𝑆
# 𝐸
# =
# 1.645
# ⋅
# 1.414
# ≈
# 2.328
# ME=z⋅SE=1.645⋅1.414≈2.328
# # Step 4: Calculate the Confidence Interval
# Finally, we calculate the confidence interval:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑀
# 𝐸
# CI=
# x
# ˉ
#  ±ME
# Calculating the lower and upper limits:
#
# 1. Lower limit:
# 𝑥
# ˉ
# −
# 𝑀
# 𝐸
# =
# 65
# −
# 2.328
# ≈
# 62.672
# x
# ˉ
#  −ME=65−2.328≈62.672
# 2. Upper limit:
# 𝑥
# ˉ
# +
# 𝑀
# 𝐸
# =
# 65
# +
# 2.328
# ≈
# 67.328
# x
# ˉ
#  +ME=65+2.328≈67.328

# %% [markdown]
# # Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.
#
# To conduct a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90% confidence level using a t-test, we can follow these steps:
#
# # Step 1: Formulate the Hypotheses
# 1. Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): Caffeine has no effect on reaction time, meaning the mean reaction time is equal to 0.25 seconds (the sample mean).
#
# 𝐻
# 0
# :
# 𝜇
# =
# 0.25
# H
# 0
# ​
#  :μ=0.25
# 2. Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): Caffeine has a significant effect on reaction time, meaning the mean reaction time is different from 0.25 seconds.
#
# 𝐻
# 𝑎
# :
# 𝜇
# ≠
# 0.25
# H
# a
# ​
#  :μ
# 
# =0.25
# # Step 2: Gather Information
# * Sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) = 0.25 seconds
# * Standard deviation (
# 𝑠
# s) = 0.05 seconds
# * Sample size (
# 𝑛
# n) = 30
# # Step 3: Calculate the Test Statistic
# We will use the formula for the one-sample t-test:
#
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# 𝑛
# t=
# n
# ​
#
# s
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# Where:
#
# 𝜇
# 0
# * μ
# 0
# ​
#   is the population mean under the null hypothesis (0.25 seconds).
# Substituting the values:
#
# 1. Calculate the standard error (SE):
# 𝑆
# 𝐸
# =
# 𝑠
# 𝑛
# =
# 0.05
# 30
# ≈
# 0.05
# 5.477
# ≈
# 0.0091
# SE=
# n
# ​
#
# s
# ​
#  =
# 30
# ​
#
# 0.05
# ​
#  ≈
# 5.477
# 0.05
# ​
#  ≈0.0091
# 2. Calculate the t-statistic:
# 𝑡
# =
# 0.25
# −
# 0.25
# 0.0091
# =
# 0
# 0.0091
# =
# 0
# t=
# 0.0091
# 0.25−0.25
# ​
#  =
# 0.0091
# 0
# ​
#  =0
# # Step 4: Determine the Degrees of Freedom
# The degrees of freedom (
# 𝑑
# 𝑓
# df) for a one-sample t-test is:
#
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# =
# 30
# −
# 1
# =
# 29
# df=n−1=30−1=29
# # Step 5: Find the Critical t-Value
# For a two-tailed test at a 90% confidence level with
# 29
# 29 degrees of freedom, the critical t-value can be found in a t-table:
#
# 𝑡
# 𝑐
# 𝑟
# 𝑖
# 𝑡
# 𝑖
# 𝑐
# 𝑎
# 𝑙
# ≈
# ±
# 1.699
# t
# critical
# ​
#  ≈±1.699
# # Step 6: Compare the Test Statistic to the Critical Value
# Now we compare our calculated t-statistic with the critical t-value:
#
# * Calculated t-statistic: 0
# * Critical t-value: ±1.699
# # Step 7: Conclusion
# Since 0 (test statistic) is less than 1.699 (critical value), we fail to reject the null hypothesis.
#
# # Final Conclusion
# There is not enough evidence at the 90% confidence level to conclude that caffeine has a significant effect on reaction time. The data suggests that the average reaction time of the participants is not significantly different from the hypothesized mean of 0.25 seconds.
